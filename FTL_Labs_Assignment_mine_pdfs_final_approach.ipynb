# %%
import glob
import pdfplumber
from IPython.display import Image

# %%
for name in glob.glob(r'./censored_ubuntu_fix/*.pdf'): 
    print(name)
# Out:
# ./censored_ubuntu_fix/resume_10.pdf
# ./censored_ubuntu_fix/resume_12.pdf
# ./censored_ubuntu_fix/resume_6.pdf
# ./censored_ubuntu_fix/resume_18.pdf
# ./censored_ubuntu_fix/resume_1.pdf
# ./censored_ubuntu_fix/resume_2.pdf
# ./censored_ubuntu_fix/resume_15.pdf
# ./censored_ubuntu_fix/resume_3.pdf
# ./censored_ubuntu_fix/resume_13.pdf
# ./censored_ubuntu_fix/resume_5.pdf
# ./censored_ubuntu_fix/resume_4.pdf
# ./censored_ubuntu_fix/resume_20.pdf
# ./censored_ubuntu_fix/resume_19.pdf
# ./censored_ubuntu_fix/resume_16.pdf
# ./censored_ubuntu_fix/resume_8.pdf
# ./censored_ubuntu_fix/resume_11.pdf
# ./censored_ubuntu_fix/resume_7.pdf
# ./censored_ubuntu_fix/resume_9.pdf
# ./censored_ubuntu_fix/resume_17.pdf

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %% [markdown]
# # Code to parse ALL pages of a single pdf and output text

# %%
name = r"./censored_ubuntu_fix/resume_10.pdf"
all_text = ""
prob_resumes = []
with pdfplumber.open(name) as pdf:
    for pdf_page in pdf.pages:
        single_page_text = pdf_page.extract_text()
        try:
            all_text = all_text + '\n' + single_page_text
        except (AttributeError,TypeError):
            prob_resumes.append(name)
            break
    if all_text.count("cid:") > 2:
        prob_resumes.append(name)
    else:
        if name in prob_resumes:
            pass
        else:
            print(color.BOLD + name + color.END)
            print(all_text)
            print("\n")
            print("___"*40)
# Out:
# ./censored_ubuntu_fix/resume_10.pdf
#
# FRANKLIN MOSES M
# Aspiring student & Proud Geek
# [ freakstyle2029@gmail.comR 2/4A6, Maris avenue, Collector’s office r½o aTdrichy, INDIA 620001
# ® cyberboyzeuz.tumblr.com¯/ linkedin.com/in/franklinmosesÓ/ +91 8344774357
# EXPERIENCE LIFE PHILOSOPHY
# Large scale face detections Work for it more than you Hope for it.
# OpenCV
# MOST PROUD OF
# DLK technologies
#  Dec 2018 ½ Chennai
# Courage I have
# 3
# • Scratch detection in vehicles To take a sinking ship and try to make it
# • Face recognition based attendance systems float
# • Emotion detection
# Persistence & Loyalty
# z
# • Hand gestured mouse
# I showed despite the hard moments
# my willingness to stay with ERIDE
# even after lots of changes in the boards
# Artificial Intelligence
# Besant Technology
# ERIDE’s growth
# `
#  May 2018 ½ Chennai Over 5000 interns got internship on
# • Churn model projects Digital marketing
# • Optimized accuracy values in Blood cell and flower dataset
# ...

# %%
print(all_text)
# Out:
# FRANKLIN MOSES M
# Aspiring student & Proud Geek
# [ freakstyle2029@gmail.comR 2/4A6, Maris avenue, Collector’s office r½o aTdrichy, INDIA 620001
# ® cyberboyzeuz.tumblr.com¯/ linkedin.com/in/franklinmosesÓ/ +91 8344774357
# EXPERIENCE LIFE PHILOSOPHY
# Large scale face detections Work for it more than you Hope for it.
# OpenCV
# MOST PROUD OF
# DLK technologies
#  Dec 2018 ½ Chennai
# Courage I have
# 3
# • Scratch detection in vehicles To take a sinking ship and try to make it
# • Face recognition based attendance systems float
# • Emotion detection
# Persistence & Loyalty
# z
# • Hand gestured mouse
# I showed despite the hard moments
# my willingness to stay with ERIDE
# even after lots of changes in the boards
# Artificial Intelligence
# Besant Technology
# ERIDE’s growth
# `
#  May 2018 ½ Chennai Over 5000 interns got internship on
# • Churn model projects Digital marketing
# • Optimized accuracy values in Blood cell and flower dataset
# Aspiring Kid in tech
# ♂
# ...

# %%
## Trial for pdf resume_14
#name = r"./censored_ubuntu_fix/resume_14.pdf"
# all_text = ""
# prob_resumes = []
# with pdfplumber.open(name) as pdf:
#     for pdf_page in pdf.pages:
#         single_page_text = pdf_page.extract_text()
#         try:
#             all_text = all_text + '\n' + single_page_text
#         except (AttributeError,TypeError):
#             prob_resumes.append(name)
#             break
#     if all_text.count("cid:") > 2:
#         prob_resumes.append(name)
#     else:
#         if name in prob_resumes:
#             pass
#         else:
#             print(color.BOLD + name + color.END)
#             print(all_text)
#             print("\n")
#             print("___"*40)
# print(all_text)

# %% [markdown]
# # Code to parse ALL pages of ALL pdfs and output text

# %%
prob_resumes = []
for name in glob.glob(r'./censored_ubuntu_fix/*.pdf'):
    #print(name)
    all_text = ""
    with pdfplumber.open(name) as pdf:
        for pdf_page in pdf.pages:
            single_page_text = pdf_page.extract_text()
            try:
                all_text = all_text + '\n' + single_page_text
            except (AttributeError,TypeError):
                prob_resumes.append(name)
                break
        if all_text.count("cid:") > 2:
            prob_resumes.append(name)
        else:
            if name in prob_resumes:
                pass
            else:
                print(color.BOLD + name + color.END)
                print(all_text)
                print("\n")
                print("___"*40)
# Out:
# ./censored_ubuntu_fix/resume_10.pdf
#
# FRANKLIN MOSES M
# Aspiring student & Proud Geek
# [ freakstyle2029@gmail.comR 2/4A6, Maris avenue, Collector’s office r½o aTdrichy, INDIA 620001
# ® cyberboyzeuz.tumblr.com¯/ linkedin.com/in/franklinmosesÓ/ +91 8344774357
# EXPERIENCE LIFE PHILOSOPHY
# Large scale face detections Work for it more than you Hope for it.
# OpenCV
# MOST PROUD OF
# DLK technologies
#  Dec 2018 ½ Chennai
# Courage I have
# 3
# • Scratch detection in vehicles To take a sinking ship and try to make it
# • Face recognition based attendance systems float
# • Emotion detection
# Persistence & Loyalty
# z
# • Hand gestured mouse
# I showed despite the hard moments
# my willingness to stay with ERIDE
# even after lots of changes in the boards
# Artificial Intelligence
# Besant Technology
# ERIDE’s growth
# `
#  May 2018 ½ Chennai Over 5000 interns got internship on
# • Churn model projects Digital marketing
# • Optimized accuracy values in Blood cell and flower dataset
# ...

# %% [markdown]
# # Trying to resolve Unexpected EOF errors caused by switching to Ubuntu, resolved by converting to pdf in Ubuntu

# %%
print("The resumes with problems being parsed are: ")
for x in prob_resumes:
    print(x)
# Out:
# The resumes with problems being parsed are:
# ./censored_ubuntu_fix/resume_4.pdf

# %% [markdown]
# # Trying pyresparser

# %%
import nltk
import en_core_web_sm

nlp = en_core_web_sm.load()

# %%
from pyresparser import ResumeParser

# %%
filename = r"./censored_ubuntu_fix/resume_1.pdf"

# %%
data = ResumeParser(filename).get_extracted_data()
# Out:
# /opt/conda/lib/python3.7/site-packages/spacy/util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.2). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
data
# Out:
# {'name': 'Pavani Chilakala',
#  'email': 'YNR@djjy38kjR9',
#  'mobile_number': None,
#  'skills': ['C', 'P'],
#  'college_name': None,
#  'degree': None,
#  'designation': None,
#  'experience': None,
#  'company_names': None,
#  'no_of_pages': 1,
#  'total_experience': 0}

# %%
filename = r"./censored_ubuntu_fix/resume_1.pdf"
data = ResumeParser(filename).get_extracted_data()
data
# Out:
# {'name': 'Pavani Chilakala',
#  'email': 'YNR@djjy38kjR9',
#  'mobile_number': None,
#  'skills': ['C', 'P'],
#  'college_name': None,
#  'degree': None,
#  'designation': None,
#  'experience': None,
#  'company_names': None,
#  'no_of_pages': 1,
#  'total_experience': 0}

# %% [markdown]
# # Trying OCR for the problematic files

# %%
from pdf2image import convert_from_path

# %%
filename = r"./censored_ubuntu_fix/resume_2.pdf"
images = convert_from_path(filename) 
  
for img in images: 
    img.save('./output.jpg', 'JPEG')

# %%
prob_resumes
# Out:
# ['./censored_ubuntu_fix/resume_4.pdf']

# %% [markdown]
# # Based on our analysis of the output

# %%
prob_resumes.append('./censored_ubuntu_fix/resume_1.pdf')
prob_resumes.append('./censored_ubuntu_fix/resume_7.pdf')
#prob_resumes.append('./censored_ubuntu_fix/resume_14.pdf')
#prob_resumes.remove('./censored_ubuntu_fix/resume_14.pdf')

# %%
prob_resumes
# Out:
# ['./censored_ubuntu_fix/resume_4.pdf',
#  './censored_ubuntu_fix/resume_1.pdf',
#  './censored_ubuntu_fix/resume_7.pdf']

# %%
for filename in prob_resumes:
    images = convert_from_path(filename)
    
    for img in images:
        display(img)
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200 at 0x7F3713C947D0>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200 at 0x7F3713C96A90>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1681x2367 at 0x7F3713C96850>

# %% [markdown]
# # Doesn't make sense to do for just the ones that errored out, we should do this for all pdfs

# %%
for name in glob.glob(r'./censored_ubuntu_fix/*.pdf'):
    images = convert_from_path(name)
    for img in images:
        print(name)
        display(img)
        print("\n")
# Out:
# ./censored_ubuntu_fix/resume_10.pdf

# %% [markdown]
# # Our non OCR approach is better
