# %% [markdown]
# # Installing dependencies:

# %%
! pip install PyPDF2

# %%
! pip install PDFMiner

# %%
! pip install PDFMiner2

# %% [markdown]
# # Imports

# %%
import PyPDF2
import requests
import json
import PDFMiner2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-35-496d9748da35> in <module>
#       2 import requests
#       3 import json
# ----> 4 import PDFMiner2
#
# ModuleNotFoundError: No module named 'PDFMiner2'

# %% [markdown]
# # Trial with PyPDF2

# %%
file = open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_7.pdf", 'rb')
pdf_reader = PyPDF2.PdfFileReader(file)
page1 = pdf_reader.getPage(0)
#print("Total Pages : {} ".format(pdf_reader.numPages))

resume = page1.extractText()
resume
# Out:
# Total Pages : 1
# 'cvBHAWNA SAPRA\n1362-A Maruti Vihar\nMG Road, Gurgaon\n9896231244/Sheyasapra5\n/sheyasapra\nEDUCATIO\nNWORK EXPERIENCE(2014-2015)DELHI PUBLIC SCHOOL, PANIPAT\n12TH- NON-MEDICAL\nDELHI PUBLIC SCHOOL PANIPAT\n(2015-2018)KURUKSHETRA UNIVERSITY,KURUKSHETRA \nB.SC GRAPHIC & ANIMATION\nINSTITUTE OF MASS COMMUNICATION & \nMEDIA(JUNE 2017-AUGUST 2017)\nDIGIT BAZAR\nGRAPHIC DESIGNER \n(INTERN)\njob- Social media post \ndesigning, logo, banner\n(SEPT 2017- PRESENT)\nMETTlGRAPHIC DESIGNER (INTERN)\njob- Social media post \ndesigning, logo, banner, \nillustration, UI UX\n(2107-Present)\nFREELANCINGLANGUAGE\nSENGLISHHINDISKILLSADOBE ILLUSRTRATOR\nADOBE PHOTOSHOP\nADOBE AFTER EFFECT\nCORAL DRAW\n'

# %%
file.read()
# Out:
# b'\nendobj\n36 0 obj\n59\nendobj\n3 0 obj\n<<\n/Type /Page\n/CropBox [0 0 605.276 851.89]\n/MediaBox [0 0 605.276 851.89]\n/Resources <<\n/ExtGState <<\n/GS0 4 0 R\n>>\n/Font <<\n/T1_0 5 0 R\n/T1_1 8 0 R\n/T1_2 11 0 R\n/TT0 14 0 R\n>>\n/ProcSet [/PDF /Text]\n/Properties <<\n/MC0 17 0 R\n>>\n/XObject <<\n/X0 32 0 R\n>>\n>>\n/ArtBox [5 5 600.276 846.89]\n/BleedBox [0 0 605.276 851.89]\n/Contents [35 0 R 18 0 R 34 0 R]\n/LastModified (D:20180427181630+05\'30\')\n/PieceInfo <<\n/Illustrator 19 0 R\n>>\n/Thumb 29 0 R\n/TrimBox [5 5 600.276 846.89]\n/Parent 2 0 R\n>>\nendobj\n38 0 obj\n<<\n/Type /Metadata\n/Subtype /XML\n/Length 26821\n>>\nstream\n<?xpacket begin=\'\xef\xbb\xbf\' id=\'W5M0MpCehiHzreSzNTczkc9d\'?>\n<x:xmpmeta xmlns:x="adobe:ns:meta/" x:xmptk="3-Heights(TM) XMP Library 5.9.1.5 (http://www.pdf-tools.com)">\n  <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">\n    <rdf:Description xmlns:dc="http://purl.org/dc/elements/1.1/" rdf:about="">\n      <dc:format>appli
# ...

# %%
import io

from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage


def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos = set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages,
                                  password=password,
                                  caching=caching,
                                  check_extractable=True):
        interpreter.process_page(page)



    fp.close()
    device.close()
    text = retstr.getvalue()
    retstr.close()
    return text

# %%
convert_pdf_to_txt(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf")
# Out:
# ---------------------------------------------------------------------------
# PDFInterpreterError                       Traceback (most recent call last)
# <ipython-input-39-b1a0c430864e> in <module>
# ----> 1 convert_pdf_to_txt(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf")
#
# <ipython-input-36-4929acb5e132> in convert_pdf_to_txt(path)
#      24                                   caching=caching,
#      25                                   check_extractable=True):
# ---> 26         interpreter.process_page(page)
#      27
#      28
#
# ~\Anaconda3\lib\site-packages\pdfminer\pdfinterp.py in process_page(self, page)
#     832             ctm = (1, 0, 0, 1, -x0, -y0)
#     833         self.device.begin_page(page, ctm)
# --> 834         self.render_contents(page.resources, page.contents, ctm=ctm)
#     835         self.device.end_page(page)
#     836         return
#
# ...

# %%
! pip install chardet

# %%
print('\nNamed with wildcard *:') 
for name in glob.glob(r'C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\*'): 
    print(name)
# Out:
# Named with wildcard *:
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_10.pdf
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_11.pdf
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_12.pdf
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_13.pdf
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_14.pdf
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_15.pdf
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_16.pdf
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_17.pdf
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_18.pdf
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_19.pdf
# ...

# %%
import glob
from chardet.universaldetector import UniversalDetector

detector = UniversalDetector()
for filename in glob.glob(r'C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\*'):
    print(filename.ljust(60)),
    detector.reset()
    for line in file(filename, 'rb'):
        detector.feed(line)
        if detector.done: break
    detector.close()
    print(detector.result)
# Out:
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-1d674fbad7ad> in <module>
#       6     print(filename.ljust(60)),
#       7     detector.reset()
# ----> 8     for line in file(filename, 'rb'):
#       9         detector.feed(line)
#      10         if detector.done: break
#
# TypeError: '_io.BufferedReader' object is not callable

# %%
detector = UniversalDetector(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf")
detector.result
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}

# %%
from PyPDF2 import PdfFileReader

def get_pdf_content_lines(pdf_file_path):
    with open(pdf_file_path) as f:
        pdf_reader = PdfFileReader(f)
        for page in pdf_reader.pages: 
            for line in page.extractText().splitlines():
                yield line

# %%
for line in get_pdf_content_lines(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf"):
    print(line)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-77-e179847a78dd> in <module>
# ----> 1 for line in get_pdf_content_lines(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf"):
#       2     print(line)
#
# <ipython-input-76-95327ac38751> in get_pdf_content_lines(pdf_file_path)
#       3 def get_pdf_content_lines(pdf_file_path):
#       4     with open(pdf_file_path) as f:
# ----> 5         pdf_reader = PdfFileReader(f)
#       6         for page in pdf_reader.pages:
#       7             for line in page.extractText().splitlines():
#
# ~\Anaconda3\lib\site-packages\PyPDF2\pdf.py in __init__(self, stream, strict, warndest, overwriteWarnings)
#    1082             stream = BytesIO(b_(fileobj.read()))
#    1083             fileobj.close()
# -> 1084         self.read(stream)
#    1085         self.stream = stream
#    1086
#
# ...

# %%
import io

def getPDFContent(path):
    content = ""
    num_pages = 10
    p = file(path, "r")
    pdf = pyPdf.PdfFileReader(p)
    for i in range(0, num_pages):
        content += pdf.getPage(i).extractText() + "\n"
    content = " ".join(content.replace(u"\xa0", " ").strip().split())
    return content

# Read each line of the PDF
pdfContent = io.StringIO(getPDFContent(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf").encode("ascii", "ignore"))
for line in pdfContent:
    doSomething(line.strip())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-e2c751c4a09e> in <module>
#      12
#      13 # Read each line of the PDF
# ---> 14 pdfContent = io.StringIO(getPDFContent(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf").encode("ascii", "ignore"))
#      15 for line in pdfContent:
#      16     doSomething(line.strip())
#
# <ipython-input-85-e2c751c4a09e> in getPDFContent(path)
#       4     content = ""
#       5     num_pages = 10
# ----> 6     p = file(path, "r")
#       7     pdf = pyPdf.PdfFileReader(p)
#       8     for i in range(0, num_pages):
#
# TypeError: '_io.BufferedReader' object is not callable

# %%
file = open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_7.pdf", 'r')
pdf_reader = PyPDF2.PdfFileReader(file)
page1 = pdf_reader.getPage(0)
#print("Total Pages : {} ".format(pdf_reader.numPages))

resume = page1.extractText()
#resume
pdfContent = io.StringIO(resume.encode("ascii", "ignore"))
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-87-30968b78a78e> in <module>
#       1 file = open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_7.pdf", 'r')
# ----> 2 pdf_reader = PyPDF2.PdfFileReader(file)
#       3 page1 = pdf_reader.getPage(0)
#       4 #print("Total Pages : {} ".format(pdf_reader.numPages))
#       5
#
# ~\Anaconda3\lib\site-packages\PyPDF2\pdf.py in __init__(self, stream, strict, warndest, overwriteWarnings)
#    1082             stream = BytesIO(b_(fileobj.read()))
#    1083             fileobj.close()
# -> 1084         self.read(stream)
#    1085         self.stream = stream
#    1086
#
# ~\Anaconda3\lib\site-packages\PyPDF2\pdf.py in read(self, stream)
#    1687         if debug: print(">>read", stream)
#    1688         # start at the end:
# -> 1689         stream.seek(-1, 2)
# ...

# %%
! pip install pdftotext
# Out:
# ...
#   Using cached pdftotext-2.1.5.tar.gz (98 kB)
# ...
#   Running setup.py clean for pdftotext
# Failed to build pdftotext
# ...
#     Running setup.py install for pdftotext: started
#     Running setup.py install for pdftotext: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\kmoudgalya\Anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\kmoudgalya\\AppData\\Local\\Temp\\pip-install-v9d_1y3l\\pdftotext\\setup.py'"'"'; __file__='"'"'C:\\Users\\kmoudgalya\\AppData\\Local\\Temp\\pip-install-v9d_1y3l\\pdftotext\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\kmoudgalya\AppData\Local\Temp\pip-wheel-t4u76klg'
#        cwd: C:\Users\kmoudgalya\AppData\Local\Temp\pip-install-v9d_1y3l\pdftotext\
#   Complete output (17 lines):
# ...

# %%
import pdftotext
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-93-b47658e7d4bc> in <module>
# ----> 1 import pdftotext
#
# ModuleNotFoundError: No module named 'pdftotext'

# %%
import glob
from chardet.universaldetector import UniversalDetector

detector = UniversalDetector()
for filename in glob.glob(r'C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\*'):
    print(filename.ljust(60)),
    detector.reset()
    for line in file(filename, 'rb'):
        detector.feed(line)
        if detector.done: break
    detector.close()
    print(detector.result)

# %%
file = open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_3.pdf", 'rb')
pdf_reader = PyPDF2.PdfFileReader(file)
page1 = pdf_reader.getPage(0)
#print("Total Pages : {} ".format(pdf_reader.numPages))

resume = page1.extractText().splitlines()
detector.reset()
for line in resume:
    detector.feed(line)
    if detector.done: break
detector.close()
print(detector.result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-248acf45f9e2> in <module>
#       7 detector.reset()
#       8 for line in resume:
# ----> 9     detector.feed(line)
#      10     if detector.done: break
#      11 detector.close()
#
# ~\Anaconda3\lib\site-packages\chardet\universaldetector.py in feed(self, byte_str)
#     130
#     131         if not isinstance(byte_str, bytearray):
# --> 132             byte_str = bytearray(byte_str)
#     133
#     134         # First check for known BOMs, since these are guaranteed to be correct
#
# TypeError: string argument without an encoding

# %%
filename = r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_7.pdf"
print(filename.ljust(60)),
detector.reset()
for line in file(filename, 'rb'):
    #detector.feed(line)
    #if detector.done: break
    chardet.detect(line)
detector.close()
print(detector.result)
# Out:
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_7.pdf
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-d7bd8591bbe9> in <module>
#       2 print(filename.ljust(60)),
#       3 detector.reset()
# ----> 4 for line in file(filename, 'rb'):
#       5     #detector.feed(line)
#       6     #if detector.done: break
#
# TypeError: '_io.BufferedReader' object is not callable

# %%
f = open(filename, "rb")
print(f.read())
# Out:
# b'%PDF-1.4\n%\xe2\xe3\xcf\xd3\n4 0 obj\n<<\n/AIS false\n/BM /Normal\n/CA 1\n/OP false\n/OPM 1\n/SA true\n/SMask /None\n/Type /ExtGState\n/ca 1\n/op false\n>>\nendobj\n7 0 obj\n<<\n/Filter /FlateDecode\n/Length 3763\n/Subtype /Type1C\n>>\nstream\nH\x89|TkTSW\x16\xbe\x97poB\xc1X\xb9\xbd\x14\x12\xcd\x8d\xcaX]Ey6<\x14\x05\x15\xcbKD\x19P\xa9tD\x12%\xc8\xcb$@\xa5\xed\x08c\x15\x08\x04\xb4\x8cm\x05\x19\x9c\xf8\x00\xe4\xa1\x8e\xf8(Ba\xa9h\x15\x90W\x10\'\x822\x01\x81\xb1t\x89\xab\x8e\xfb\xc6\x03k\xe6\x06\xff\xf4\xd7\xac\xb3\xd6^g\xef}\xcew\xf6\xde\xe7\xdb\x1b\xc7\xac\xad0\x1c\xc7\xed\xb7l\x8d\x88\x0c\x0f\xfa80Y\x91\xb62\\\xb9/Qc\xb12\xac\x18g\x1d\xad\xd9\x85v4rG\xc5o\xdf\xbe\r\'\xa0u>\xbcXpu\xe1|\x95=f\x85\xe3\xc6\x89\ri\xe9\x07U\x96\x1bRw__\x0f\x17\x8b\xf4\x9a\x93\xde.R\x0f77\xb79\xe9%\r\x94\xa7\xedQH\xa3\x0e\xaa5\x8a\x14\xb54$5!M\x95\x9e\xa6\x8a\xd7(\xe4\xab\xa4\x81\xc9\xc9\xd29\x08\xb5T\xa5P+T\x99\x16\xe3f\x0e5^.U\xaa\xa5\n\xa5&Q\xa1\x92\xc6s\xce}J\xee\xbeJ!\x97jT\xf1rEJ\xbcj\xbf4\xcd\xe2\x
# ...

# %%
chardet.detect(f.read())
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}

# %% [markdown]
# #  This print kind of works for files where the encoding is ok

# %%
file = open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_3.pdf", 'rb')

pdf_reader = PyPDF2.PdfFileReader(file)
page1 = pdf_reader.getPage(0)

resume = page1.extractText().splitlines()
resume
# Out:
# ['As an inquisitive and enthusiastic young mind, I chose to pursue  an education in the ˜eld ',
#  'of engineering after my high school graduation. The knowledge so acquired in the four ',
#  '',
#  'years of formal education is highly valuable. As I laid down my options for further studies, ',
#  '',
#  'I thoroughly analyzed where my true interests lie. Hence, I chose to pursue a Master™s in ',
#  '',
#  'the ˜eld of apparel design. Today, as I learn and progress, I constantly make an effort to ',
#  '',
#  'understand and explore the endless possibilities of utilizing both the technical and creative ',
#  '',
#  'knowledge.',
#  'aishwarya.pammi@gmail.com',
#  '+91 73378 34067WORK EXPERIENCE',
#  'EDUCATION',
#  'TOOLS',
#  'SKILLSŁ Ł ',
#  'Ł ',
#  'Ł AISHWARYA ',
#  '22 Mar 1992Bengaluru, IndiaDOB',
#  'ADOBE INDESIGN',
#  'ADOBE PHOTOSHOP',
#  ' ',
#  'ADOBE ILLUSTRATOR',
#  ' ',
#  'MS OFFICESir. M. Visvesvaraya Institute of Technology, Bengaluru, India.',
# ...

# %% [markdown]
# # Trying to change the encoding

# %%
import codecs

# %%
file = open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_3.pdf", 'rb')
with codecs.open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_3.pdf", 'r', encoding = 'ANSI') as file:
  lines = file.read()

# %%
lines
# Out:
# '%PDF-1.7\n%âãÏÓ\n5 0 obj\n<<\n/Filter /FlateDecode\n/Length 2574\n/N 3\n>>\nstream\nH‰œ–yTSw\x16Ç\x7foÉž\x90•°Ãc\r[€°\x06\x905la‘\x1d\x04Q\x08I\x08\x01\x12BHØ\x05AD\x05\x14ED„ª•2ÖmtFOE\x9d.®c\xad\x0eÖ}êÒ\x03õ0êè8´\x16×Ž\x9d\x178G\x9dNg¦Óï\x1fï÷9÷wïïÝß½÷\x9dó\x00\xa0\'¥ªµÕ0\x0b\x00\x8dÖ\xa0ÏJŒÅ\x16\x15\x14b¤\t\x00\x03\n \x02\x11\x002y\xad.-;!\x07à’ÆK°ZÜ\tü‹ž^\x07\x90i½"LÊÀ0ðÿ‰-×é\r\x00@\x198\x07(”µrœ;q®ª7èLö\x19œy¥•&†Q\x13ëñ\x04q¶4±jž½ç|æ9ÚÄ\n\x8dV\x81³)g\x9dB£0ñiœW×\x19•8#©8wÕ©•õ8_ÅÙ¥Ê¨QãüÜ\x14«QÊj\x01@é&»A)/ÇÙ\x0fgº>\'K‚ó\x02\x00ÈtÕ;\\ú\x0e\x1b”\r\x06Ó¥$ÕºF½ZUnÀÜå\x1e˜(4TŒ%)ë«”\x06ƒ0C&¯”é\x15˜¤Z£“i\x1b\x01˜¿óœ8¦Úbx‘ƒE¡ÁÁB\x7f\x1fÑ;…ú¯›¿P¦ÞÎÓ“Ì¹žAü\x0bom?çW=\n€x\x16¯Íú·¶Ò-\x00Œ¯\x04Àòæ[›Ëû\x000ñ¾\x1d¾øÎ}ø¦y)7\x18ta¾¾õõõ>j¥ÜÇTÐ7úŸ\x0e¿@ï¼ÏÇtÜ›ò`qÊ2™±Ê€™ê&¯®ª6ê±Z\x9dL®Ä„?\x1dâ_\x1døóyxg)Ë”z¥\x16\x8fÈÃ§L\xadUáíÖ*Ô\x06uµ\x16SkÿS\x13\x7feØO4?×¸¸c¯\x01¯Ø\x07°.ò\x00ò·\x0b\x00åÒ\x00R´\rß\x81Þô-•’\x072ð5ßáÞüÜÏ\tú÷Sá>Ó£V\xadš‹“då`r£¾n~ÏôY\x02\x02\xa0\x02&à\x01+`\x0fœ\x81;\x10\x02\x7f\x10\x02Â
# ...

# %% [markdown]
# # Confirmed that we can read ANSI etc, Now to convert them all to a common format:

# %%
for name in glob.glob(r'C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\Test1\*'): 
    with codecs.open(name, 'r', encoding = 'ANSI') as file:
      lines = file.read()
    with codecs.open(name[:-4] + "_NEW" + name[-4:] , 'w', encoding = 'UTF16') as file:
      file.write(lines)

# %%
name[-4:]
# Out:
# '.pdf'

# %%
file = open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\Test2\resume_1_NEW.pdf", 'rb')

pdf_reader = PyPDF2.PdfFileReader(file)
page1 = pdf_reader.getPage(0)

resume = page1.extractText().splitlines()
resume
# Out:
# ---------------------------------------------------------------------------
# PdfReadError                              Traceback (most recent call last)
# <ipython-input-146-5736f64e397e> in <module>
#       1 file = open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\Test2\resume_1_NEW.pdf", 'rb')
#       2
# ----> 3 pdf_reader = PyPDF2.PdfFileReader(file)
#       4 page1 = pdf_reader.getPage(0)
#       5
#
# ~\Anaconda3\lib\site-packages\PyPDF2\pdf.py in __init__(self, stream, strict, warndest, overwriteWarnings)
#    1082             stream = BytesIO(b_(fileobj.read()))
#    1083             fileobj.close()
# -> 1084         self.read(stream)
#    1085         self.stream = stream
#    1086
#
# ~\Anaconda3\lib\site-packages\PyPDF2\pdf.py in read(self, stream)
#    1694         while line[:5] != b_("%%EOF"):
#    1695             if stream.tell() < last1K:
# -> 1696                 raise utils.PdfReadError("EOF marker not found")
# ...

# %% [markdown]
# # Pikepdfs can work with corrupted pdfs

# %%
! pip install pikepdf

# %%
import pikepdf
pdf = pikepdf.Pdf.open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\Test2\resume_2_NEW.pdf", 'rb')
# Out:
# ---------------------------------------------------------------------------
# PdfError                                  Traceback (most recent call last)
# <ipython-input-147-8d0bcd7dc7c2> in <module>
#       1 import pikepdf
# ----> 2 pdf = pikepdf.Pdf.open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\Test2\resume_2_NEW.pdf", 'rb')
#
# ~\Anaconda3\lib\site-packages\pikepdf\_methods.py in open(filename_or_stream, password, hex_password, ignore_xref_streams, suppress_warnings, attempt_recovery, inherit_page_attributes, access_mode, allow_overwriting_input)
#     827                 tmp_stream = BytesIO()
#     828                 shutil.copyfileobj(pdf_file, tmp_stream)
# --> 829         pdf = Pdf._open(
#     830             tmp_stream or filename_or_stream,
#     831             password=password,
#
# ...

# %% [markdown]
# # Seems like we need pdfminer.six, but pdfpulmber might be even better because it is built on top of pdfminer.six, lets try using this

# %%
! pip install pdfplumber
# Out:
# ...
#   Created wheel for pdfplumber: filename=pdfplumber-0.5.24-py3-none-any.whl size=31145 sha256=42f31f490f4b7476868bb02354d1b029bb1f34b80e4b2835881569c133ba5cdc
#   Stored in directory: c:\users\kmoudgalya\appdata\local\pip\cache\wheels\2b\02\eb\8e0c88d08e0675b767895d4bcf54c0d4da1b37579b00409e0e
# Successfully built pdfplumber
# ...

# %%
import pdfplumber

# %%
with pdfplumber.open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf") as pdf:
    first_page = pdf.pages[0]
    print(first_page.extract_text())
# Out:
# Pavani Chilakala
# (cid:211) (cid:84)(cid:28)(cid:112)(cid:28)(cid:77)(cid:66)(cid:88)(cid:43)(cid:63)(cid:66)(cid:72)(cid:28)(cid:70)(cid:28)(cid:72)(cid:28)(cid:82)(cid:107)(cid:106)(cid:33)(cid:59)(cid:75)(cid:28)(cid:66)(cid:72)(cid:88)(cid:43)(cid:81)(cid:75) (cid:37) (cid:252) (cid:89)(cid:78)(cid:82)(cid:64)(cid:100)(cid:106)(cid:106)(cid:121)(cid:51)(cid:56)(cid:107)(cid:106)(cid:82)(cid:57) (cid:37) (cid:74) (cid:34)(cid:28)(cid:77)(cid:59)(cid:28)(cid:72)(cid:81)(cid:96)(cid:50)(cid:45) (cid:65)(cid:77)(cid:47)(cid:66)(cid:28)
# (cid:6)(cid:31)(cid:48)(cid:30)(cid:28)(cid:47)(cid:36)(cid:42)(cid:41)
# ...

# %%
with pdfplumber.open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf") as pdf:
    im = pdf.pages[0].to_image()
    im.draw_rects(p0.extract_words())
# Out:
# ---------------------------------------------------------------------------
# DelegateError                             Traceback (most recent call last)
# <ipython-input-157-05a817f54a69> in <module>
#       1 with pdfplumber.open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf") as pdf:
# ----> 2     im = pdf.pages[0].to_image()
#       3     im.draw_rects(p0.extract_words())
#       4
#
# ~\Anaconda3\lib\site-packages\pdfplumber\page.py in to_image(self, **conversion_kwargs)
#     285         if "resolution" not in conversion_kwargs:
#     286             kwargs["resolution"] = DEFAULT_RESOLUTION
# --> 287         return PageImage(self, **kwargs)
#     288
#     289     def __repr__(self):
#
# ~\Anaconda3\lib\site-packages\pdfplumber\display.py in __init__(self, page, original, resolution)
#      59         self.page = page
#      60         if original is None:
# ---> 61             self.original = get_page_image(
# ...

# %% [markdown]
# # Seems like mupdf can deal with these cid characters

# %%
! pip install PyMuPDF

# %%
import fitz
doc = fitz.open(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf")

# %%
page = doc[0]

# %%
page.getText("text")
# Out:
# 'PavaniChilakala\n� ����������������������������� � � �������������� � � ���������� �����\n���������\n���� ������� ��� ������ ����� �� ������������\n������� ������ �������\n�� ���� �� �������� �������\n������� � ���������\n���� ���\n���������� ������ �������\n������ ������ �������\n������������ �� �����\n�������� � ���������\n���� ���\n������������\n������ ������ �������\n���\n���� � �������\n���� ���\n������\n���������\n����� ���� �������� ����������� ���\n���������\n������ ����\n�������\n����� �������\n�� ���������� ������ �����\n������������\n���������� ��� ������ �������������\n����� ���� �������\n�� ����� � ���� ������� ����� ��� �������� ���� ����� ���� ��� �������� � ���� ���� ������� ��������\n���������� ��������� � ���� ��������� ���� �������� �� ��� ��� ��������������\n�������������������������������������������������������\n����������\n���������� ���������� ��� ���� ���������� �������������\n����������� ���\n�� ����� � ���� ������� ���������� �������� ��� ��� ��� ��� �����
# ...

# %%
page.getDICT()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-182-6155f00a047f> in <module>
# ----> 1 page.getDICT()
#
# AttributeError: 'Page' object has no attribute 'getDICT'

# %%
x = page.getText("text")

# %%
for name in glob.glob(r'C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\Test1\*'): 
    with codecs.open(name, 'r', encoding = 'ANSI') as file:
      lines = file.read()
    with codecs.open(name[:-4] + "_NEW.txt" , 'w', encoding = 'UTF8') as file:
      file.write(lines)

# %%
for name in glob.glob(r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\Test1\*.txt"):
    print(name)
# Out:
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\Test1\resume_1_NEW.txt
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\Test1\resume_2_NEW.txt
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\Test1\resume_3_NEW.txt
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\Test1\resume_4_NEW.txt
# C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\Test1\resume_5_NEW.txt

# %%
f = r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf"
import codecs
fichier = codecs.open(f, "r", encoding="utf-8")
fichierTemp = codecs.open("tempASCII", "w", encoding="ascii", errors="ignore")
fichierTemp.write(contentOfFile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-194-4a753ff6d09c> in <module>
#       3 fichier = codecs.open(f, "r", encoding="utf-8")
#       4 fichierTemp = codecs.open("tempASCII", "w", encoding="ascii", errors="ignore")
# ----> 5 fichierTemp.write(contentOfFile)
#
# NameError: name 'contentOfFile' is not defined

# %%
! pip install textract
# Out:
# ...
# ERROR: pdfplumber 0.5.24 has requirement pdfminer.six==20200517, but you'll have pdfminer-six 20181108 which is incompatible.
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3969 sha256=f65f67a2ae411539a15c48f130f0441d8de164d63cd96c7647c27c4a39ac5e2d
#   Stored in directory: c:\users\kmoudgalya\appdata\local\pip\cache\wheels\55\f0\2c\81637d42670985178b77df6d41b9b6c6dc18c94818447414b9
# ...
#   Created wheel for python-pptx: filename=python_pptx-0.6.18-py3-none-any.whl size=275709 sha256=956aeda95964b0618aefbf83bac391e9bd066f608866e2c8ed3f225ddac5704d
#   Stored in directory: c:\users\kmoudgalya\appdata\local\pip\cache\wheels\11\2b\97\d82ca57932fa62d52c723024419c5ec3b7c0f7ecf0a0f06332
# ...
#   Created wheel for EbookLib: filename=EbookLib-0.17.1-py3-none-any.whl size=38167 sha256=49f29ac9ddd7394497e060fdd332c87df231bb66dde5d731d7fa9d1920308e63
# ...

# %%
! pip uninstall pdfminer.six
# Out:
# ^C

# %%
import textract

# %%
text = textract.process(
    r"C:\Users\kmoudgalya\Desktop\FTL\ML Assignment test dataset\censored\resume_1.pdf",
    method='tesseract',
    language='en')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\textract\parsers\utils.py in run(self, args)
#      81         try:
# ---> 82             pipe = subprocess.Popen(
#      83                 args,
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#
# ...
